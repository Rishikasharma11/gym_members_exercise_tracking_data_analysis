# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
data = pd.read_csv("gym_members_exercise_tracking.csv")

# %%
data
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    object
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    object
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
# ...

# %%
data.describe()
# Out:
#               Age  Weight (kg)  Height (m)     Max_BPM     Avg_BPM  \
# count  973.000000   973.000000   973.00000  973.000000  973.000000
# mean    38.683453    73.854676     1.72258  179.883864  143.766701
# std     12.180928    21.207500     0.12772   11.525686   14.345101
# min     18.000000    40.000000     1.50000  160.000000  120.000000
# 25%     28.000000    58.100000     1.62000  170.000000  131.000000
# 50%     40.000000    70.000000     1.71000  180.000000  143.000000
# 75%     49.000000    86.000000     1.80000  190.000000  156.000000
# max     59.000000   129.900000     2.00000  199.000000  169.000000
#
#        Resting_BPM  Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count   973.000000                973.000000       973.000000      973.000000
# mean     62.223022                  1.256423       905.422405       24.976773
# std       7.327060                  0.343033       272.641516        6.259419
# ...

# %%
data.isnull()
# Out:
#        Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0    False   False        False       False    False    False        False
# 1    False   False        False       False    False    False        False
# 2    False   False        False       False    False    False        False
# 3    False   False        False       False    False    False        False
# 4    False   False        False       False    False    False        False
# ..     ...     ...          ...         ...      ...      ...          ...
# 968  False   False        False       False    False    False        False
# 969  False   False        False       False    False    False        False
# 970  False   False        False       False    False    False        False
# 971  False   False        False       False    False    False        False
# 972  False   False        False       False    False    False        False
#
# ...

# %%
df = data[['Age', 'Gender', 'Fat_Percentage']]
df
# Out:
#      Age  Gender  Fat_Percentage
# 0     56    Male            12.6
# 1     46  Female            33.9
# 2     32  Female            33.4
# 3     25    Male            28.8
# 4     38    Male            29.2
# ..   ...     ...             ...
# 968   24    Male            10.0
# 969   25    Male            25.0
# 970   59  Female            18.8
# 971   32    Male            28.2
# 972   46    Male            28.8
#
# [973 rows x 3 columns]

# %%
df = data.aggregate({'Age': 'min'})
print("Minimum age:\n", df)
# Out:
# Minimum age:
#  Age    18
# dtype: int64

# %%
df = data.aggregate({'Age': 'max'})
print("Minimum age:\n", df)
# Out:
# Minimum age:
#  Age    59
# dtype: int64

# %%
df = data.groupby('Gender').aggregate({'Calories_Burned' : ['min', 'max']})
df
# Out:
#        Calories_Burned
#                    min     max
# Gender
# Female           303.0  1625.0
# Male             331.0  1783.0

# %%
min_max_sum = data.groupby('Gender').aggregate({'BMI' : ['min', 'max', 'sum']})
min_max_sum
# Out:
#           BMI
#           min    max       sum
# Gender
# Female  12.47  35.04  10500.26
# Male    12.32  49.84  13739.24

# %%
df = data.groupby('Workout_Type')['Gender'].value_counts()
df
# Out:
# Workout_Type  Gender
# Cardio        Male      129
#               Female    126
# HIIT          Male      114
#               Female    107
# Strength      Male      135
#               Female    123
# Yoga          Male      133
#               Female    106
# Name: count, dtype: int64

# %%
df = data.groupby('Gender')['Fat_Percentage'].value_counts()
df
# Out:
# Gender  Fat_Percentage
# Female  28.1              8
#         32.8              8
#         26.1              7
#         29.2              7
#         30.6              7
#                          ..
# Male    23.1              1
#         24.6              1
#         25.1              1
#         26.3              1
#         27.7              1
# Name: count, Length: 290, dtype: int64

# %%
df = data.groupby('Workout_Type').agg({'Age' : 'mean'})
df
# Out:
#                     Age
# Workout_Type
# Cardio        37.670588
# HIIT          38.945701
# Strength      38.949612
# Yoga          39.234310

# %%
df = data.groupby('Gender').agg({'Weight (kg)' : 'mean', 'Experience_Level' : 'mean', 'Calories_Burned' : 'mean', 'Fat_Percentage' : 'mean'})
df
# Out:
#         Weight (kg)  Experience_Level  Calories_Burned  Fat_Percentage
# Gender
# Female    60.939827          1.807359       862.248918       27.656710
# Male      85.531115          1.812133       944.455969       22.553816

# %%
data
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
data.columns = data.columns.str.replace('_', ' ')
data
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max BPM  Avg BPM  Resting BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session Duration (hours)  Calories Burned Workout Type  Fat Percentage  \
# ...

# %%
high_calorie_burners = data[data['Calories Burned'] > 500]
high_calorie_burners
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max BPM  Avg BPM  Resting BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session Duration (hours)  Calories Burned Workout Type  Fat Percentage  \
# ...

# %%
def bmi_category(bmi):
    if bmi < 18.5:
        return 'Underweight'
    elif 18.5 <= bmi < 24.9:
        return 'Normal weight'
    elif 25 <= bmi < 29.9:
        return 'Overweight'
    else:
        return 'Obese'

data['BMI_Category'] = data['BMI'].apply(bmi_category)
data[['BMI', 'BMI_Category']]
# Out:
#        BMI   BMI_Category
# 0    30.20          Obese
# 1    32.00          Obese
# 2    24.71  Normal weight
# 3    18.41    Underweight
# 4    14.39    Underweight
# ..     ...            ...
# 968  28.77     Overweight
# 969  25.69     Overweight
# 970  19.50  Normal weight
# 971  37.74          Obese
# 972  33.38          Obese
#
# [973 rows x 2 columns]

# %%
group_by_gender_workout = data.groupby(['Gender', 'Workout Type'])['Calories Burned'].mean()
group_by_gender_workout
# Out:
# Gender  Workout Type
# Female  Cardio          834.793651
#         HIIT            869.953271
#         Strength        863.097561
#         Yoga            886.122642
# Male    Cardio          933.077519
#         HIIT            978.228070
#         Strength        954.066667
#         Yoga            916.789474
# Name: Calories Burned, dtype: float64

# %%
pivot_table = data.pivot_table(values='Fat Percentage', index='Gender', columns='Workout Type', aggfunc='mean')
pivot_table
# Out:
# Workout Type     Cardio       HIIT   Strength       Yoga
# Gender
# Female        27.938889  27.585981  28.143089  26.828302
# Male          22.915504  21.528070  23.014074  22.615038

# %%
sorted_data = data.sort_values(by='Calories Burned', ascending=False)
sorted_data[['Calories Burned', 'Gender', 'Workout Type']].head(10)
# Out:
#      Calories Burned  Gender Workout Type
# 910           1783.0    Male     Strength
# 712           1766.0    Male         HIIT
# 511           1725.0    Male     Strength
# 124           1701.0    Male     Strength
# 90            1688.0    Male         HIIT
# 646           1675.0    Male     Strength
# 572           1646.0    Male         HIIT
# 728           1634.0    Male     Strength
# 99            1625.0  Female       Cardio
# 475           1622.0    Male         HIIT

# %%
import plotly.express as px

fig = px.scatter_matrix(data.head(50), dimensions=['Weight (kg)', 'Calories Burned', 'BMI'],
                        color='Gender', hover_data=['Age'], title='Scatter Matrix: Weight, Calories Burned, and BMI')
fig.show()

# %%
fig = px.scatter(data.head(50), x='Weight (kg)', y='Calories Burned', color='Gender',
                 title='Weight vs Calories Burned', size='BMI', hover_data=['Age'])
fig.show()

# %%
fig = px.bar(data.head(50), x = 'Water Intake (liters)', y = 'Experience Level', 
             title = 'Average water intake according to experience')
fig.show()

# %%
fig = px.histogram(data.head(20),  x = 'Gender', y = 'Calories Burned', color = 'Gender',
             title = 'Average calories burned by male and female')
fig.show()

# %%
fig = px.scatter(data.head(50), x='Age', y='Session Duration (hours)', color='Gender', 
              title='Session Duration vs Age', size = 'Age')
fig.show()

# %%
fig = px.imshow(data,
                title='Correlation Heatmap',
                color_continuous_scale='Viridis',  # You can choose other color scales too
                labels=dict(x='Features', y='Features'))
fig.show()
